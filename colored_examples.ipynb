# %%
import numpy as np
import matplotlib.pyplot as plt

from simulation import MichelsonSimulation
from visual import showPattern
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-255cd4851347> in <module>
#       3
#       4 from simulation import MichelsonSimulation
# ----> 5 from visual import showPattern
#
# ~\RealMichelson\visual.py in <module>
#      10
#      11 # Make sure that we are using QT5
# ---> 12 matplotlib.use('Qt5Agg')
#      13 from PyQt5 import QtCore, QtWidgets
#      14 from PyQt5.QtWidgets import QWidget, QFormLayout, QPushButton, QLineEdit, QInputDialog
#
# c:\users\41-巴巴罗萨\opencv\lib\site-packages\matplotlib\__init__.py in use(backend, force)
#    1153                 # user does not have the libraries to support their
#    1154                 # chosen backend installed.
# -> 1155                 plt.switch_backend(name)
#    1156             except ImportError:
#    1157                 if force:
#
# c:\users\41-巴巴罗萨\opencv\lib\site-packages\matplotlib\pyplot.py in switch_backend(newbackend)
#     257     backend_name = cbook._backend_module_name(newbackend)
#     258
# --> 259     class backend_mod(matplotlib.backend_bases._Backend):
#     260         locals().update(vars(importlib.import_module(backend_name)))
#     261
#
# c:\users\41-巴巴罗萨\opencv\lib\site-packages\matplotlib\pyplot.py in backend_mod()
#     258
#     259     class backend_mod(matplotlib.backend_bases._Backend):
# --> 260         locals().update(vars(importlib.import_module(backend_name)))
#     261
#     262     required_framework = _get_required_interactive_framework(backend_mod)
#
# c:\python 3.8.5\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# c:\users\41-巴巴罗萨\opencv\lib\site-packages\matplotlib\backends\backend_qt5agg.py in <module>
#       9 from .. import cbook
#      10 from .backend_agg import FigureCanvasAgg
# ---> 11 from .backend_qt5 import (
#      12     QtCore, QtGui, QtWidgets, _BackendQT5, FigureCanvasQT, FigureManagerQT,
#      13     NavigationToolbar2QT, backend_version)
#
# c:\users\41-巴巴罗萨\opencv\lib\site-packages\matplotlib\backends\backend_qt5.py in <module>
#      14     _Backend, FigureCanvasBase, FigureManagerBase, NavigationToolbar2,
#      15     TimerBase, cursors, ToolContainerBase, StatusbarBase, MouseButton)
# ---> 16 import matplotlib.backends.qt_editor.figureoptions as figureoptions
#      17 from matplotlib.backends.qt_editor._formsubplottool import UiSubplotTool
#      18 from . import qt_compat
#
# c:\users\41-巴巴罗萨\opencv\lib\site-packages\matplotlib\backends\qt_editor\figureoptions.py in <module>
#       9
#      10 from matplotlib import cbook, cm, colors as mcolors, markers, image as mimage
# ---> 11 from matplotlib.backends.qt_compat import QtGui
#      12 from matplotlib.backends.qt_editor import _formlayout
#      13
#
# c:\users\41-巴巴罗萨\opencv\lib\site-packages\matplotlib\backends\qt_compat.py in <module>
#     171         break
#     172     else:
# --> 173         raise ImportError("Failed to import any qt binding")
#     174 else:  # We should not get there.
#     175     raise AssertionError("Unexpected QT_API: {}".format(QT_API))
#
# ImportError: Failed to import any qt binding

# %%
# %%time

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 1.2e-6, 0])

simulation.insertSpecSource([-20, 0, 0], np.ones_like(np.arange(380, 781, 5)) / 400)

simulation.changeToLocal()

showPattern(simulation, isColored=True)
# Out:
# Wall time: 7.62 s

# %%
# %%time

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 2.5e-6, 0])

simulation.insertSpecSource([-20, 0, 0], np.ones_like(np.arange(380, 781, 5)) / 400)

simulation.changeToLocal()

showPattern(simulation, isColored=True)
# Out:
# Wall time: 7.76 s

# %%
# %%time

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 2.5e-6, 0])

simulation.insertSource([-20, 0, 0], 589, 0.035)
simulation.insertSource([-20, 0, 0], 589.6, 0.035)

simulation.changeToLocal()

showPattern(simulation, isColored=True)
# Out:
# Wall time: 682 ms

# %%
# %%time

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 2.5e-6, 0])

for y in np.arange(-40,40,20):
    for z in np.arange(-40,40,20):
        simulation.insertSource([-20, y, z], 589, 0.005)

simulation.changeToLocal()
simulation.localInterference()

showPattern(simulation, isColored=True)
# Out:
# Wall time: 3.28 s

# %%
# %%time

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1e-3, 0, 0], [-1, 0, 0])

simulation.insertSource([-20, 0, 0], 589, 0.03)
simulation.insertSource([-20, 0, 0], 589.6, 0.03)


simulation.changeToLocal()
simulation.localInterference()

showPattern(simulation, isColored=True)
# Out:
# Wall time: 819 ms

# %%
# %%time

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1e-3, 0, 0], [-1, 0, 0])

for lam in np.arange(600-50,600+50,5):
    simulation.insertSource([-20, 0, 0], lam, 0.03)

simulation.changeToLocal()
simulation.localInterference()

showPattern(simulation, isColored=True)
# Out:
# Wall time: 3.83 s

# %%
# %%time

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1e-3, 0, 0], [-1, 0, 0])

for y in np.arange(-50,50,5):
    simulation.insertSource([-20, y, 0], 589, 0.003)

simulation.changeToLocal()
simulation.localInterference()

showPattern(simulation, isColored=True)
# Out:
# Wall time: 3.89 s

# %%
showPattern(simulation, isColored=False)

# %%
# %%time

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1, 0, 0], [-1, 0, 0])

simulation.insertSource([-20, 0, 0], 689, 50000)


simulation.changeToNonlocal()
pattern = simulation.nonlocalInterference()

showPattern(simulation, isColored=True)
# Out:
# Wall time: 682 ms
