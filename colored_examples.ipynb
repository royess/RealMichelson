# %%
import numpy as np
import matplotlib.pyplot as plt

from simulation import MichelsonSimulation
from visual import showPattern

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 1.5e-6, 0])

simulation.insertSource([-20, 0, 0], 590, 0.25)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# CPU times: user 534 ms, sys: 106 ms, total: 641 ms
# Wall time: 447 ms

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 1.2e-6, 0])

simulation.insertSpecSource([-20, 0, 0], np.ones_like(np.arange(380, 781, 5)) / 400)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# CPU times: user 6.19 s, sys: 91 ms, total: 6.28 s
# Wall time: 6.26 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 2.5e-6, 0])

simulation.insertSpecSource([-20, 0, 0], np.ones_like(np.arange(380, 781, 5)) / 400)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# CPU times: user 6.12 s, sys: 97.9 ms, total: 6.22 s
# Wall time: 6.21 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 1e-4, 0])
simulation.insertSource([-20, 0, 0], 635)
simulation.changeToNonlocal()

showPattern(ax, simulation, True)
# Out:
# CPU times: user 520 ms, sys: 12.8 ms, total: 533 ms
# Wall time: 500 ms

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 1.5e-6, 0])

simulation.insertSource([-20, 0, 0], 590, 0.3)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# CPU times: user 464 ms, sys: 22.5 ms, total: 487 ms
# Wall time: 463 ms

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 2.5e-6, 0])

for y in np.arange(-20,20,10):
    for z in np.arange(-20,20,10):
        simulation.insertSource([-20, y, z], 589, 0.003)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# CPU times: user 1.43 s, sys: 19.7 ms, total: 1.45 s
# Wall time: 1.44 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 2.5e-6, 0])

for y in np.arange(-20,20,10):
    for z in np.arange(-20,20,10):
        simulation.insertSource([-20, y, z], 589, 0.03)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# CPU times: user 1.59 s, sys: 29.4 ms, total: 1.62 s
# Wall time: 1.62 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1e-3, 0, 0], [-1, 0, 0])

simulation.insertSource([-20, 0, 0], 589, 0.03)
simulation.insertSource([-20, 0, 0], 589.6, 0.03)


simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# CPU times: user 546 ms, sys: 30.4 ms, total: 577 ms
# Wall time: 568 ms

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1e-3, 0, 0], [-1, 0, 0])

for lam in np.arange(600-50,600+50,5):
    simulation.insertSource([-20, 0, 0], lam, 0.005)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# CPU times: user 1.82 s, sys: 9.21 ms, total: 1.82 s
# Wall time: 1.82 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1e-3, 0, 0], [-1, 0, 0])

for y in np.arange(-50,50,5):
    simulation.insertSource([-20, y, 0], 589, 0.003)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# CPU times: user 1.8 s, sys: 19.5 ms, total: 1.82 s
# Wall time: 1.81 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1, 0, 0], [-1, 0, 0])

simulation.insertSource([-20, 0, 0], 689, 50)


simulation.changeToNonlocal()

showPattern(ax, simulation, True)
# Out:
# CPU times: user 457 ms, sys: 10.8 ms, total: 467 ms
# Wall time: 458 ms
