# %%
import numpy as np
import matplotlib.pyplot as plt

from simulation import MichelsonSimulation
from visual import showPattern

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 1.2e-6, 0])

simulation.insertSpecSource([-20, 0, 0], np.ones_like(np.arange(380, 781, 5)) / 400)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# Wall time: 18.4 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 2.5e-6, 0])

simulation.insertSpecSource([-20, 0, 0], np.ones_like(np.arange(380, 781, 5)) / 400)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# Wall time: 18.2 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 1.5e-6, 0])

simulation.insertSource([-20, 0, 0], 589, False, 0.035)
#simulation.insertSource([-20, 0, 0], 590, False, 0.015)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# Wall time: 1.39 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 1.5e-6, 0])

simulation.insertSource([-20, 0, 0], 589, True, 0.15)
#simulation.insertSource([-20, 0, 0], 590, False, 0.015)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# Wall time: 4.24 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 2.5e-6, 0])

for y in np.arange(-20,20,10):
    for z in np.arange(-20,20,10):
        simulation.insertSource([-20, y, z], 589, False, 0.003)

#print(simulation.source_list)
simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# Wall time: 4.64 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100, 0, 0], [-1, 2.5e-6, 0])

for y in np.arange(-20,20,10):
    for z in np.arange(-20,20,10):
        simulation.insertSource([-20, y, z], 589, True, 0.03)

#print(simulation.source_list)
simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# Wall time: 52.3 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1e-3, 0, 0], [-1, 0, 0])

simulation.insertSource([-20, 0, 0], 589, False, 0.03)
simulation.insertSource([-20, 0, 0], 589.6, False, 0.03)


simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# Wall time: 1.54 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1e-3, 0, 0], [-1, 0, 0])

for lam in np.arange(600-50,600+50,5):
    simulation.insertSource([-20, 0, 0], lam, False, 0.005)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# Wall time: 5.29 s

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1e-3, 0, 0], [-1, 0, 0])

for y in np.arange(-50,50,5):
    simulation.insertSource([-20, y, 0], 589, False, 0.003)

simulation.changeToLocal()

showPattern(ax, simulation, True)
# Out:
# Wall time: 5.46 s

# %%
fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1e-3, 0, 0], [-1, 0, 0])

for y in np.arange(-50,50,5):
    simulation.insertSource([-20, y, 0], 589, False, 0.003)

simulation.changeToLocal()

showPattern(ax, simulation, False)

# %%
# %%time

fig, ax = plt.subplots()

simulation = MichelsonSimulation()
simulation.initialMirrorG([0, 0, 0], [-1, 1, 0])
simulation.initialMirrorM1([0, 100, 0], [0, -1, 0])
simulation.initialMirrorM2([100-1, 0, 0], [-1, 0, 0])

simulation.insertSource([-20, 0, 0], 689, False, 50)


simulation.changeToNonlocal()

showPattern(ax, simulation, True)
# Out:
# Wall time: 1.45 s
